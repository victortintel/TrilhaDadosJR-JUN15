# %% [markdown]
# Victor Tintel Martins - Trilha Inicial Ciência de Dados Jr

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Utilize esses dados e transforme em arquivo .CSV, você vai utilizar para realizar a análise utilizando o Python com pandas e Matplotlib/Seaborn para visualização de dados."
#
# - Os dados abaixo foram tirados do github do desafio, colocado no excel e depois transformado em arquivo CVS.

# %%
df = pd.read_csv("DADOSTRANSFORMADO.csv")
df
# Out:
#     ID                                  Nome do Curso  Quantidade de Vendas  \
# 0    1             Introdução à Programação em Python                    50
# 1    2             Desenvolvimento Web com HTML e CSS                    30
# 2    3  JavaScript Avançado: Frameworks e Bibliotecas                    20
# 3    4                 Introdução ao Machine Learning                    15
# 4    5        Desenvolvimento Mobile com React Native                    25
# 5    6                   Arquitetura de Microserviços                    12
# 6    7                     Banco de Dados SQL e NoSQL                    18
# 7    8           Segurança da Informação: Fundamentos                    10
# 8    9                        Cloud Computing com AWS                    22
# 9   10          DevOps: Integração e Entrega Contínua                     8
# 10  11             Desenvolvimento Web com HTML e CSS                    20
# ...

# %% [markdown]
# # Desafios Propostos:
#
# 1- Calcular a receita total gerada pela venda dos cursos.
#
# 2- Identificar o curso com o maior número de vendas.
#
# 3- Visualizar a distribuição das vendas ao longo do tempo através de gráficos.

# %%
# 1 - Calcular a receita total gerada pela venda dos cursos.
# Primeiramente vamos calcular o valor da quantidade de vendas pelo preço unitário para descobrir o valor total de 
# vendas de cada produto, para aí sim nós calcularmos a receita total que será a soma de todos eles.

df["Preço total"] = df["Quantidade de Vendas"] * df["Preço Unitário"]
df
# Out:
#     ID                                  Nome do Curso  Quantidade de Vendas  \
# 0    1             Introdução à Programação em Python                    50
# 1    2             Desenvolvimento Web com HTML e CSS                    30
# 2    3  JavaScript Avançado: Frameworks e Bibliotecas                    20
# 3    4                 Introdução ao Machine Learning                    15
# 4    5        Desenvolvimento Mobile com React Native                    25
# 5    6                   Arquitetura de Microserviços                    12
# 6    7                     Banco de Dados SQL e NoSQL                    18
# 7    8           Segurança da Informação: Fundamentos                    10
# 8    9                        Cloud Computing com AWS                    22
# 9   10          DevOps: Integração e Entrega Contínua                     8
# 10  11             Desenvolvimento Web com HTML e CSS                    20
# ...

# %%
df.describe()
# Out:
#               ID  Quantidade de Vendas  Preço Unitário  Preço total
# count  25.000000             25.000000       25.000000    25.000000
# mean   13.000000             17.960000       83.900000  1309.404000
# std     7.359801             10.921996       21.984843   412.195665
# min     1.000000              5.000000       39.900000   549.500000
# 25%     7.000000             10.000000       69.900000   999.000000
# 50%    13.000000             15.000000       79.900000  1258.200000
# 75%    19.000000             20.000000       99.900000  1498.500000
# max    25.000000             50.000000      119.900000  2197.800000

# %%
# 1 - Calcular a receita total gerada pela venda dos cursos.
df["Preço total"].cumsum()
# Out:
# 0      1995.0
# 1      3792.0
# 2      5390.0
# 3      6888.5
# 4      8636.0
# 5      9714.8
# 6     11153.0
# 7     12252.0
# 8     14449.8
# 9     15409.0
# 10    16607.0
# 11    17805.5
# 12    18804.5
# 13    20062.7
# 14    20781.9
# 15    21740.7
# 16    22290.2
# 17    23788.7
# 18    24508.1
# 19    26303.6
# 20    27801.1
# 21    29239.3
# 22    30438.1
# 23    31836.1
# 24    32735.1
# Name: Preço total, dtype: float64

# %% [markdown]
# 1 - Calcular a receita total gerada pela venda dos cursos.
# A receita total gerada pela venda dos cursos é de 32.735,1 reais.

# %% [markdown]
# Desafios Propostos:
#
# 1- Calcular a receita total gerada pela venda dos cursos. (RESOLVIDO)
#
# 2- Identificar o curso com o maior número de vendas.
#
# 3- Visualizar a distribuição das vendas ao longo do tempo através de gráficos.

# %%
# 2 - Identificar o curso com o maior número de vendas.

df["Quantidade de Vendas"].idxmax()
# Out:
# 0

# %% [markdown]
# 2 - Identificamos acima que o curso om maior número de vendas é o curso de ID = 0, portanto, olhando no DataFrame descobrimos que é o curso Introdução à Programação em Python.

# %% [markdown]
# Desafios Propostos:
#
# 1- Calcular a receita total gerada pela venda dos cursos. (RESOLVIDO)
#
# 2- Identificar o curso com o maior número de vendas. (RESOLVIDO)
#
# 3- Visualizar a distribuição das vendas ao longo do tempo através de gráficos.

# %%
# 3- Visualizar a distribuição das vendas ao longo do tempo através de gráficos.
# Nesse primeiro gráfico estará representado por um gráfico de linha.

grafico1 = df.plot.line(x="Data", y="Quantidade de Vendas", linewidth=2, color="b").grid()

# %%
# Nesse segundo gráfico estará representado por um gráfico de barras.

grafico2 = df.plot.bar(x="Data", y="Quantidade de Vendas", linewidth=2, color="b")

# %% [markdown]
# Desafios Propostos:
#
# 1- Calcular a receita total gerada pela venda dos cursos. (RESOLVIDO)
#
# 2- Identificar o curso com o maior número de vendas. (RESOLVIDO)
#
# 3- Visualizar a distribuição das vendas ao longo do tempo através de gráficos. (RESOLVIDO)
